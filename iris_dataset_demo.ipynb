# %%
from sklearn import datasets

# %%
iris_datasets = datasets.load_iris()

# %%
X = iris_datasets.data[:]

# %%
x_count = len(X.flat)
x_min = X[:, 0].min()-.5
x_max = X[:, 0].max()+ 2
x_mean = X[:, 0].mean()

# %%
x_count,x_min,x_max,x_mean
# Out:
# (300, np.float64(3.8), np.float64(9.9), np.float64(5.843333333333334))
