# %%
import numpy, pandas
import matplotlib.pyplot as plt
import urllib.request
url = 'https://raw.githubusercontent.com/datasets/sample-dataset/main/headbrain.csv'  # Replace with actual URL
urllib.request.urlretrieve(url, 'headbrain.csv')
data = pandas.read_csv('headbrain.csv')
plt.rcParams['figure.figsize'] = (21.0, 11.0)
data = pandas.read_csv('headbrain.csv')
print(data.shape)
data.head()
